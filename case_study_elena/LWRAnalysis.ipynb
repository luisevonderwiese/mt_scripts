# %%
import ete3
from ete3 import Tree
import matplotlib.pyplot as plt

#t = Tree("delta_statistics/rd_output/geo_duration.tree.morpho.lwr.tree")
t = Tree("delta_statistics/rd_output/cognate_ie_compatible.tree.morpho.lwr.tree")
LWRS = []
for node in t.traverse():
    if hasattr(node,"LWR"):
        LWRS.append(node.LWR)
plt.hist(LWRS, bins = 20)
#plt.xticks(range(len(LWRS)-9)[::8], rotation=70)
plt.xticks(range(len(LWRS)-30)[::8], rotation=70)
plt.xlabel("LWR")
plt.ylabel("Number of nodes")
plt.show()
